# %%
! pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\akiot\anaconda3\lib\site-packages (2.6.1)

# %%
import pygame
import time
import random

pygame.init()

crash_sound = pygame.mixer.Sound("C:/Users/akiot/car.wav")
pygame.mixer.music.load("C:/Users/akiot/racing.wav")
start_sound = pygame.mixer.Sound("C:/Users/akiot/start.wav")

display_width = 800
display_height = 600

black = (0,0,0)
white = (255,255,255)
red = (200,0,0)
green = (0,200,0)

bright_red = (255,0,0)
bright_green = (0,255,0)

block_color = (53,115,255)

gameDisplay = pygame.display.set_mode((display_width, display_height))
pygame.display.set_caption('A bit Racey')
clock = pygame.time.Clock()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
car_width = 73

# %%
carImg = pygame.image.load('C:/Users/akiot/racecar.png')
gameIcon = pygame.image.load('C:/Users/akiot/racecar.png')

pygame.display.set_icon(gameIcon)

pause = False

# %%
def things_dodged(count):
    font = pygame.font.SysFont("comicsansms", 25)
    text = font.render("Dodged: "+str(count), True, black)
    gameDisplay.blit(text, (0,0))

# %%
def things(thingx, thingy, thingw, thingh, color):
    pygame.draw.rect(gameDisplay, color, [thingx, thingy, thingw, thingh])

# %%
def car(x,y):
    gameDisplay.blit(carImg, (x,y))

# %%
def text_objects(text, font):
    textSurface = font.render(text, True, black)
    return textSurface, textSurface.get_rect()

# %%
#def message_display(text):
#    largeText = pygame.font.SysFont('comicsansms',115)
#    TextSurf, TextRect = text_objects(text, largeText)
#    TextRect.center = ((display_width/2),(display_height/2))
#    gameDisplay.blit(TextSurf, TextRect)
    
#    pygame.display.update()
    
#    time.sleep(2)
  
#    game_loop()

# %%
def crash():
    
    pygame.mixer.music.stop()
    pygame.mixer.Sound.play(crash_sound)
    
    largeText = pygame.font.SysFont("comicsansms",115)
    TextSurf, TextRect = text_objects("You Crashed", largeText)
    TextRect.center = ((display_width/2),(display_height/2))
    gameDisplay.blit(TextSurf, TextRect)
    
    while True:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()
        
        button("Play Again", 150,450,100,50, green, bright_green, game_loop)
        button("Quit", 550,450,100,50, red, bright_red, quitgame)
        
        pygame.mixer.music.stop()
        pygame.mixer.Sound.play(start_sound)

        pygame.display.update()
        clock.tick(15)

# %%
def button(msg, x, y, w, h, ic, ac, action=None):
    
    mouse = pygame.mouse.get_pos()
    click = pygame.mouse.get_pressed()
    
        
    #print(click)
        
    if x+w > mouse[0] >x and y+h > mouse[1]>y:
        pygame.draw.rect(gameDisplay, ac, (x,y,w,h))
        if click[0] == 1 and action != None:
            action()
    else:
        pygame.draw.rect(gameDisplay, ic, (x,y,w,h))   
    smallText = pygame.font.SysFont("comicsansms", 20)
    textSurf, textRect = text_objects(msg, smallText)
    textRect.center = ((x+(w/2)), (y+(h/2)))
    gameDisplay.blit(textSurf, textRect)

# %%
def quitgame():
    pygame.quit()
    quit()

# %%
def unpause():
    global pause
    pygame.mixer.music.unpause()
    pause = False

# %%
def paused():
      
    pygame.mixer.music.pause()
    
    largeText = pygame.font.SysFont('comicsansms',115)
    TextSurf, TextRect = text_objects("Paused", largeText)
    TextRect.center = ((display_width/2),(display_height/2))
    gameDisplay.blit(TextSurf, TextRect)
    
    while pause:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()
                
        button("Continue",150,450,100,50,green, bright_green, unpause)
        button("Quit", 550,450,100,50, red, bright_red, quitgame)
               
              
        pygame.display.update()
        clock.tick(15)

# %%
def game_intro():
    
    intro = True
    
    while intro:
        for event in pygame.event.get():
            #print(event)
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()
        
        gameDisplay.fill(white)
        largeText = pygame.font.SysFont('comicsansms',115)
        TextSurf, TextRect = text_objects("A bit Racey", largeText)
        TextRect.center = ((display_width/2),(display_height/2))
        gameDisplay.blit(TextSurf, TextRect)
        
        button("GO!",150,450,100,50,green, bright_green, game_loop)
        button("Quit", 550,450,100,50, red, bright_red, quitgame)
        
        pygame.mixer.Sound.play(start_sound)
        pygame.mixer.music.stop()
        
        pygame.display.update()
        clock.tick(15)

# %%
def game_loop():
    
    global pause
    
    pygame.mixer.music.play(-1)
    
    x = (display_width*0.45)
    y = (display_height*0.8)
    
    x_change = 0
   
    
    thing_startx = random.randrange(0, display_width)
    thing_starty= -600
    thing_speed = 2
    thing_width = 100
    thing_height = 100
    
    thingCount = 1
    
    dodged = 0
    
    gameExit = False
    
    while not gameExit:
    
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                quit()          
        
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x_change = -5
                if event.key == pygame.K_RIGHT:
                    x_change = 5
                if event.key == pygame.K_PAUSE:
                    pause = True
                    paused()
                    
            if event.type == pygame.KEYUP:
                if event.key == pygame.K_LEFT or event.key == pygame.K_RIGHT:
                    x_change = 0
    
        x += x_change
    
        gameDisplay.fill(white)
        
        things(thing_startx, thing_starty, thing_width, thing_height, block_color)
        thing_starty += thing_speed
        
        car(x,y)
        things_dodged(dodged)
        
        if x > display_width - car_width or x < 0:
            crash()
        
        if thing_starty > display_height:
            thing_starty = 0 - thing_height
            thing_startx = random.randrange(0, display_width)
            dodged += 1
            thing_speed += 1
            thing_width += (dodged * 1.2)
            
        if y < thing_starty+thing_height:
            print('y crossover')
            
            if (x > thing_startx and x < thing_startx+thing_width 
                or x+car_width > thing_startx 
                and x+car_width < thing_startx+thing_width):
                print('x crossover')
                crash()

        pygame.display.update()
        clock.tick(60)

# %%
game_intro()
game_loop()
pygame.quit()
quit()
# Out:
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# y crossover
# x crossover
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 game_intro()
#       2 game_loop()
#       3 pygame.quit()
#
# Cell In[16], line 18, in game_intro()
#      15 TextRect.center = ((display_width/2),(display_height/2))
#      16 gameDisplay.blit(TextSurf, TextRect)
# ---> 18 button("GO!",150,450,100,50,green, bright_green, game_loop)
#      19 button("Quit", 550,450,100,50, red, bright_red, quitgame)
#      21 pygame.mixer.Sound.play(start_sound)
#
# Cell In[12], line 12, in button(msg, x, y, w, h, ic, ac, action)
#      10     pygame.draw.rect(gameDisplay, ac, (x,y,w,h))
#      11     if click[0] == 1 and action != None:
# ---> 12         action()
#      13 else:
#      14     pygame.draw.rect(gameDisplay, ic, (x,y,w,h))
#
# Cell In[17], line 72, in game_loop()
#      68     if (x > thing_startx and x < thing_startx+thing_width
#      69         or x+car_width > thing_startx
#      70         and x+car_width < thing_startx+thing_width):
#      71         print('x crossover')
# ---> 72         crash()
#      74 pygame.display.update()
#      75 clock.tick(60)
#
# Cell In[11], line 18, in crash()
#      15         quit()
#      17 button("Play Again", 150,450,100,50, green, bright_green, game_loop)
# ---> 18 button("Quit", 550,450,100,50, red, bright_red, quitgame)
#      20 pygame.mixer.music.stop()
#      21 pygame.mixer.Sound.play(start_sound)
#
# Cell In[12], line 15, in button(msg, x, y, w, h, ic, ac, action)
#      13 else:
#      14     pygame.draw.rect(gameDisplay, ic, (x,y,w,h))
# ---> 15 smallText = pygame.font.SysFont("comicsansms", 20)
#      16 textSurf, textRect = text_objects(msg, smallText)
#      17 textRect.center = ((x+(w/2)), (y+(h/2)))
#
# File ~\anaconda3\Lib\site-packages\pygame\sysfont.py:460, in SysFont(name, size, bold, italic, constructor)
#     457 if italic and not gotitalic:
#     458     set_italic = True
# --> 460 return constructor(fontname, size, set_bold, set_italic)
#
# File ~\anaconda3\Lib\site-packages\pygame\sysfont.py:378, in font_constructor(fontpath, size, bold, italic)
#     366 def font_constructor(fontpath, size, bold, italic):
#     367     """
#     368     pygame.font specific declarations
#     369
#    (...)
#     375     :return: A font.Font object.
#     376     """
# --> 378     font = Font(fontpath, size)
#     379     if bold:
#     380         font.set_bold(True)
#
# error: font not initialized

# %%
# https://pythonprogramming.net/adding-sounds-music-pygame/
